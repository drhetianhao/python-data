# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('../../../data/X_train.csv')
X_test = pd.read_csv('../../../data/X_test.csv')
y_train = pd.read_csv('../../../data/y_train.csv')
y_test = pd.read_csv('../../../data/y_test.csv')

X_train.head()
# Out:
#                                           clean_text
# 0               ['ive', 'reached', 'sch', 'already']
# 1  ['wan2', 'win', 'meetgreet', 'westlife', '4', ...
# 2  ['oh', 'right', 'ok', 'ill', 'make', 'sure', '...
# 3  ['uncle', 'abbey', 'happy', 'new', 'year', 'ab...
# 4  ['hard', 'true', 'much', 'show', 'amp', 'expre...

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'ive': 3991,
#  'reached': 5976,
#  'sch': 6341,
#  'already': 1005,
#  'wan2': 7861,
#  'win': 8017,
#  'meetgreet': 4705,
#  'westlife': 7963,
#  'm8': 4574,
#  'currently': 2228,
#  'tour': 7474,
#  '1unbreakable': 369,
#  '2untamed': 456,
#  '3unkempt': 518,
#  'text': 7240,
#  '12': 273,
#  '83049': 725,
#  'cost': 2136,
#  '50p': 593,
#  'std': 6900,
#  'oh': 5266,
#  'right': 6175,
#  'ok': 5273,
#  'ill': 3818,
#  'make': 4611,
#  'sure': 7067,
#  'loads': 4438,
#  'work': 8092,
#  'day': 2300,
#  'got': 3357,
#  'really': 5994,
#  'nasty': 5011,
#  'cough': 2144,
#  'today': 7403,
#  'dry': 2607,
#  'shot': 6528,
#  'help': 3566,
#  'uncle': 7609,
#  'abbey': 816,
#  'happy': 3503,
#  'new': 5070,
#  'year': 8242,
#  'abiola': 823,
#  'hard': 3504,
#  'true': 7524,
#  'much': 4947,
#  'show': 6536,
#  'amp': 1028,
#  'express': 2865,
#  'love': 4503,
#  'someonethat': 6716,
#  'hurt': 3766,
#  'leave': 4329,
#  'get': 3263,
#  'seperated': 6429,
#  'ud': 7587,
#  'evening': 2796,
#  'orange': 5345,
#  'brings': 1597,
#  'ringtones': 6186,
#  'time': 7363,
#  'chart': 1846,
#  'heroes': 3583,
#  'free': 3118,
#  'hit': 3618,
#  'week': 7926,
#  'go': 3307,
#  'pics': 5566,
#  'wap': 7870,
#  'stop': 6930,
#  'receiving': 6012,
#  'tips': 7372,
#  'reply': 6106,
#  'im': 3821,
#  'inside': 3899,
#  'officestill': 5252,
#  'filling': 2982,
#  'formsdon': 3096,
#  'know': 4212,
#  'sleeping': 6632,
#  'bags': 1280,
#  'blanket': 1460,
#  'paper': 5431,
#  'phone': 5551,
#  'details': 2409,
#  'anything': 1078,
#  'else': 2702,
#  'call': 1699,
#  'plz': 5633,
#  'number': 5205,
#  'shows': 6543,
#  'coveragd': 2161,
#  'area': 1125,
#  'urgnt': 7683,
#  'vasai': 7736,
#  'reach': 5974,
#  '4o': 571,
#  'clock': 1959,
#  'jurong': 4102,
#  'point': 5658,
#  'crazy': 2181,
#  'available': 1228,
#  'bugis': 1642,
#  'great': 3394,
#  'world': 8100,
#  'la': 4247,
#  'buffet': 1640,
#  'cine': 1930,
#  'amore': 1026,
#  'wat': 7885,
#  'parked': 5449,
#  'next': 5080,
#  'mini': 4792,
#  'coming': 2022,
#  'think': 7307,
#  'welcome': 7943,
#  'select': 6401,
#  'o2': 5223,
#  'service': 6437,
#  'added': 880,
#  'benefits': 1399,
#  'specially': 6789,
#  'trained': 7487,
#  'advisors': 909,
#  'mobile': 4847,
#  'dialling': 2426,
#  '402': 526,
#  'germany': 3262,
#  'pence': 5503,
#  'per': 5510,
#  'minute': 4800,
#  'fixed': 3019,
#  'line': 4398,
#  'via': 7757,
#  'access': 842,
#  '0844': 53,
#  '861': 749,
#  '85': 741,
#  'prepayment': 5765,
#  'direct': 2468,
#  'tmrw': 7393,
#  'finishing': 3003,
#  'doors': 2547,
#  'attracts': 1206,
#  'brothas': 1611,
#  'cab': 1684,
#  'availablethey': 1230,
#  'pick': 5563,
#  'drop': 2595,
#  'door': 2546,
#  'steps': 6910,
#  'life': 4373,
#  'style': 6991,
#  'garments': 3221,
#  'account': 852,
#  'please': 5618,
#  'oops': 5319,
#  'bit': 1443,
#  'kkwhen': 4202,
#  'going': 3324,
#  'sent': 6424,
#  'scores': 6349,
#  'sophas': 6749,
#  'secondary': 6376,
#  'application': 1098,
#  'schools': 6344,
#  'thinking': 7309,
#  'applying': 1102,
#  'research': 6120,
#  'also': 1009,
#  'contact': 2094,
#  'joke': 4066,
#  'ogunrinde': 5265,
#  'school': 6343,
#  'one': 5299,
#  'less': 4351,
#  'expensive': 2851,
#  'ones': 5301,
#  'geeeee': 3243,
#  'barely': 1307,
#  'stand': 6871,
#  'ready': 5983,
#  'ltgt': 4536,
#  'hey': 3593,
#  'happen': 3494,
#  'de': 2312,
#  'alright': 1006,
#  'dont': 2540,
#  'prize': 5804,
#  'another': 1058,
#  'customer': 2234,
#  'tc': 7175,
#  'wwwtcbiz': 8189,
#  '18': 338,
#  '150pmin': 308,
#  'polo': 5666,
#  'ltd': 4531,
#  'suite': 7027,
#  '373': 493,
#  'london': 4462,
#  'w1j': 7820,
#  '6hl': 655,
#  'back': 1273,
#  'busy': 1663,
#  'thanx': 7262,
#  'puttin': 5896,
#  'da': 2248,
#  'fone': 3064,
#  'want': 7865,
#  'send': 6413,
#  'something': 6721,
#  'sell': 6408,
#  'fast': 2921,
#  'easy': 2648,
#  'money': 4873,
#  'girl': 3283,
#  'propose': 5852,
#  'seing': 6400,
#  'ur': 7676,
#  'bloody': 1481,
#  'funky': 3188,
#  'shit': 6502,
#  'fucking': 3172,
#  'faceasssssholeeee': 2879,
#  'guessin': 3441,
#  'aint': 960,
#  'gonna': 3334,
#  'print': 5794,
#  'outs': 5384,
#  'ssindia': 6857,
#  'draw': 2572,
#  'series': 6432,
#  'many': 4634,
#  'years': 8243,
#  'south': 6770,
#  'african': 922,
#  'soil': 6706,
#  'driving': 2591,
#  'training': 7488,
#  'always': 1015,
#  'saying': 6332,
#  'welp': 7949,
#  'credits': 2188,
#  'topped': 7459,
#  'httpwwwbubbletextcom': 3731,
#  'renewal': 6089,
#  'pin': 5580,
#  'tgxxrz': 7252,
#  'eh': 2681,
#  'remember': 6074,
#  'spell': 6796,
#  'name': 4997,
#  'yes': 8253,
#  'naughty': 5021,
#  'wet': 7966,
#  'asked': 1172,
#  '3mobile': 510,
#  '0870': 61,
#  'chatlines': 1853,
#  'inclu': 3850,
#  'mins': 4796,
#  'india': 3866,
#  'cust': 2230,
#  'servs': 6440,
#  'sed': 6387,
#  'l8er': 4244,
#  'mega': 4711,
#  'bill': 1426,
#  'giv': 3289,
#  'bailiff': 1283,
#  'due': 2618,
#  'days': 2304,
#  '250': 401,
#  '800': 697,
#  'cal': 1692,
#  'sir': 6592,
#  'meeting': 4707,
#  'hmm': 3630,
#  'yeah': 8240,
#  'grooved': 3412,
#  'looking': 4471,
#  'forward': 3100,
#  'pound': 5716,
#  'special': 6785,
#  'nonenowhere': 5146,
#  'ikno': 3814,
#  'doesdiscountshitinnit': 2517,
#  'hi': 3598,
#  'msg': 4928,
#  'meim': 4714,
#  'office': 5250,
#  'sorry': 6753,
#  'man': 4621,
#  'accidentally': 846,
#  'left': 4335,
#  'silent': 6571,
#  'last': 4290,
#  'night': 5094,
#  'didnt': 2434,
#  'check': 1861,
#  'til': 7360,
#  'bout': 1535,
#  'nite': 5108,
#  'wasnåõt': 7881,
#  'fault': 2931,
#  'spouse': 6835,
#  'pmt': 5635,
#  'sumthin': 7036,
#  '4give': 565,
#  'shldxxxx': 6511,
#  'fool': 3068,
#  'cheat': 1858,
#  'others': 5364,
#  'usf': 7700,
#  'guess': 3438,
#  'might': 4772,
#  'well': 7945,
#  'take': 7132,
#  'car': 1753,
#  'theory': 7286,
#  'argument': 1133,
#  'wins': 8028,
#  'situation': 6605,
#  'loses': 4484,
#  'person': 5526,
#  'argue': 1131,
#  'friends': 3148,
#  'kick': 4166,
#  'say': 6330,
#  'correct': 2128,
#  'monthly': 4886,
#  'amount': 1027,
#  'terrible': 7229,
#  'pay': 5482,
#  'till': 7361,
#  '6months': 660,
#  'juz': 4105,
#  'remembered': 6075,
#  'gotta': 3362,
#  'bathe': 1325,
#  'dog': 2519,
#  'satanic': 6313,
#  'imposter': 3837,
#  'meneed': 4730,
#  'priceso': 5787,
#  'itmay': 3976,
#  'destiny': 2407,
#  'keep': 4143,
#  'said': 6280,
#  'pray': 5746,
#  'mind': 4785,
#  'ìï': 8332,
#  'comin': 2021,
#  'fetch': 2961,
#  'us': 7690,
#  'oredi': 5353,
#  'panasonic': 5424,
#  'bluetoothhdset': 1490,
#  'nokia': 5136,
#  'motorola': 4910,
#  'doublemins': 2556,
#  'doubletxt': 2557,
#  'contract': 2103,
#  'mobileupd8': 4851,
#  '08000839402': 40,
#  '2optout': 446,
#  'yup': 8317,
#  'liao': 4362,
#  'chachi': 1821,
#  'tried': 7515,
#  'calling': 1717,
#  'unable': 7606,
#  'pl': 5591,
#  'give': 3290,
#  'missed': 4813,
#  'tiz': 7384,
#  'kanagu': 4121,
#  'glad': 3295,
#  'made': 4590,
#  'thats': 7272,
#  'late': 4293,
#  'good': 3336,
#  'tomorrow': 7429,
#  'iam': 3779,
#  'sleep': 6630,
#  'lol': 4459,
#  'knew': 4208,
#  'saw': 6329,
#  'dollar': 2531,
#  'store': 6941,
#  'joys': 4084,
#  'father': 2927,
#  'john': 4059,
#  'ans': 1059,
#  'ths': 7343,
#  'hav': 3522,
#  'iq': 3944,
#  'tis': 7378,
#  'ias': 3780,
#  'question': 5911,
#  'try': 7533,
#  'answer': 1061,
#  'representative': 6111,
#  'freephone': 3130,
#  '0808': 49,
#  '145': 294,
#  '4742': 554,
#  '9am11pm': 801,
#  'guaranteed': 3431,
#  '1000': 244,
#  'cash': 1781,
#  '5000': 590,
#  'christmas': 1923,
#  'occasion': 5234,
#  'celebrated': 1809,
#  'reflection': 6043,
#  'values': 7730,
#  'desires': 2399,
#  'affectionsamp': 917,
#  'traditions': 7484,
#  'ideal': 3798,
#  'went': 7952,
#  'project': 5836,
#  'centre': 1815,
#  'mate': 4660,
#  'spoke': 6822,
#  'mag': 4595,
#  'people': 5508,
#  'deliver': 2368,
#  'end': 2720,
#  'month': 4885,
#  '24th': 399,
#  'sept': 6430,
#  'talk': 7141,
#  'later': 4298,
#  'done': 2537,
#  'accept': 841,
#  'dayu': 2309,
#  'brother': 1612,
#  'sister': 6597,
#  'lover': 4509,
#  'dear1': 2322,
#  'best1': 1403,
#  'clos1': 1961,
#  'lvblefrnd': 4562,
#  'jstfrnd': 4088,
#  'cutefrnd': 2240,
#  'lifpartnr': 4380,
#  'belovd': 1392,
#  'swtheart': 7109,
#  'bstfrnd': 1626,
#  'rply': 6232,
#  'means': 4693,
#  'enemy': 2727,
#  'doesnt': 2518,
#  'stalk': 6867,
#  'profiles': 5831,
#  'hungry': 3754,
#  'gay': 3228,
#  'guys': 3453,
#  'feeling': 2951,
#  '08718730555': 138,
#  '10pmin': 262,
#  'texts': 7250,
#  '08712460324': 101,
#  'congrats': 2079,
#  '3g': 503,
#  'videophones': 7767,
#  '09061744553': 188,
#  'videochat': 7766,
#  'wid': 8001,
#  'mates': 4661,
#  'play': 5608,
#  'java': 4021,
#  'games': 3210,
#  'dload': 2504,
#  'polyh': 5671,
#  'music': 4971,
#  'noline': 5141,
#  'rentl': 6095,
#  'bx420': 1676,
#  'ip4': 3939,
#  '5we': 621,
#  '150pm': 306,
#  'jus': 4103,
#  'home': 3658,
#  'first': 3010,
#  'sis': 6596,
#  'using': 7703,
#  'net': 5058,
#  'tell': 7208,
#  'finishes': 3002,
#  'feel': 2949,
#  'like': 4387,
#  'dick': 2430,
#  'facebook': 2880,
#  'messages': 4752,
#  'sup': 7048,
#  'town': 7476,
#  'whenever': 7977,
#  'hold': 3648,
#  'connections': 2084,
#  'maybe': 4682,
#  'hour': 3702,
#  'two': 7568,
#  'cool': 2119,
#  'head': 3530,
#  'battery': 1329,
#  'died': 2439,
#  'come': 2015,
#  'getting': 3270,
#  'gram': 3377,
#  'wheres': 7984,
#  'place': 5592,
#  'told': 7418,
#  'gautham': 3226,
#  'cant': 1743,
#  'pls': 5625,
#  'message': 4746,
#  '545': 602,
#  'lor': 4478,
#  'ya': 8226,
#  'dinner': 2463,
#  'together': 7412,
#  'omg': 5294,
#  'thing': 7304,
#  'cat': 1789,
#  'worms': 8105,
#  'bad': 1276,
#  'pass': 5462,
#  '69669': 644,
#  'collect': 2000,
#  'polyphonic': 5673,
#  'normal': 5158,
#  'gprs': 3368,
#  'charges': 1842,
#  'apply': 1099,
#  'enjoy': 2736,
#  'tones': 7434,
#  'usually': 7710,
#  'unconscious': 7612,
#  'children': 1899,
#  'adults': 902,
#  'may': 4680,
#  'behave': 1381,
#  'abnormally': 826,
#  'hows': 3715,
#  'scotland': 6352,
#  'hope': 3679,
#  'showing': 6541,
#  'jjc': 4052,
#  'tendencies': 7220,
#  'care': 1758,
#  'live': 4425,
#  'dream': 2575,
#  'fuck': 3169,
#  'double': 2554,
#  'txts': 7576,
#  'tariffs': 7155,
#  'latest': 4300,
#  'sonyericsson': 6739,
#  'bluetooth': 1489,
#  'call2optouthf8': 1703,
#  'gettin': 3269,
#  'arty': 1157,
#  'collages': 1997,
#  'mo': 4843,
#  'tryin': 7534,
#  'ne': 5028,
#  'way': 7899,
#  'roast': 6197,
#  'min': 4782,
#  'lovely': 4507,
#  'shall': 6469,
#  'pa': 5403,
#  'bath': 1324,
#  'spoil': 6820,
#  'bed': 1363,
#  'chuckin': 1927,
#  'red': 6029,
#  'green': 3401,
#  'black': 1450,
#  'trainners': 7489,
#  'save': 6325,
#  'carryin': 1775,
#  'bac': 1272,
#  'train': 7486,
#  'nothing': 5169,
#  'making': 4615,
#  'everybodys': 2805,
#  'speed': 6793,
#  'met': 4761,
#  'stranger': 6952,
#  'choose': 1916,
#  'friend': 3146,
#  'long': 4465,
#  'stands': 6874,
#  'friendship': 3150,
#  'never': 5066,
#  'ends': 2725,
#  'lets': 4356,
#  'forever': 3081,
#  'gud': 3433,
#  'nitz': 5112,
#  'kiss': 4188,
#  'sound': 6765,
#  'effects': 2671,
#  'gorgeous': 3353,
#  'isnt': 3961,
#  'kind': 4180,
#  'needs': 5046,
#  'smile': 6669,
#  'brighten': 1590,
#  'youd': 8283,
#  'marry': 4649,
#  'knw': 4220,
#  'drink': 2583,
#  'milk': 4777,
#  'msgs': 4932,
#  'dis': 2473,
#  'wit': 8041,
#  'different': 2448,
#  'nos': 5162,
#  'law': 4310,
#  'alone': 1002,
#  'alive': 989,
#  'church': 1928,
#  'holla': 3654,
#  'chill': 1902,
#  '6hrs': 657,
#  'could': 2146,
#  'pain': 5415,
#  'surgical': 7071,
#  'emergency': 2710,
#  'see': 6388,
#  'unfolds': 7625,
#  'okay': 5274,
#  'things': 7306,
#  'quick': 5915,
#  'ryder': 6263,
#  'unsoldnow': 7650,
#  'gibbs': 3274,
#  'buzz': 1672,
#  'goes': 3319,
#  'miss': 4811,
#  'babe': 1263,
#  'moment': 4866,
#  'againloving': 930,
#  'kkim': 4200,
#  'tirunelvali': 7376,
#  'spend': 6799,
#  'taking': 7138,
#  'dress': 2580,
#  'moneyi': 4875,
#  'feb': 2944,
#  'watching': 7889,
#  'cartoon': 1779,
#  'listening': 4418,
#  'eve': 2792,
#  'temple': 7217,
#  'picking': 5565,
#  'various': 7733,
#  'points': 5659,
#  'yeovil': 8250,
#  'motor': 4909,
#  'hours': 3704,
#  '530': 598,
#  'max': 4674,
#  'st': 6859,
#  'andre': 1040,
#  'virgils': 7784,
#  'cream': 2183,
#  'ay': 1252,
#  'wana': 7862,
#  'meet': 4704,
#  'satì': 6322,
#  'wkg': 8054,
#  'sat': 6312,
#  'water': 7891,
#  'logging': 4450,
#  'desert': 2397,
#  'geoenvironmental': 3258,
#  'implications': 3832,
#  'ni8': 5083,
#  'dearslp': 2330,
#  'welltake': 7947,
#  'careswt': 1766,
#  'dreamsmuah': 2578,
#  'ee': 2666,
#  'na': 4987,
#  'poortiyagi': 5684,
#  'odalebeku': 5241,
#  'hanumanji': 3493,
#  '1hanuman': 351,
#  '2bajarangabali': 419,
#  '3maruti': 507,
#  '4pavanaputra': 572,
#  '5sankatmochan': 617,
#  '6ramaduth': 662,
#  '7mahaveer': 690,
#  'janarige': 4014,
#  'ivatte': 3990,
#  'kalisidare': 4116,
#  'saturday': 6321,
#  'olage': 5286,
#  'ondu': 5298,
#  'news': 5075,
#  'keluviri': 4147,
#  'maretare': 4640,
#  'inde': 3862,
#  'dodda': 2515,
#  'problum': 5819,
#  'nalli': 4996,
#  'siguviri': 6569,
#  'idu': 3804,
#  'matra': 4666,
#  'neglet': 5052,
#  'since': 6580,
#  'thank': 7257,
#  'ho': 3641,
#  'use': 7694,
#  'type': 7580,
#  'words': 8089,
#  'dnt': 2505,
#  'wnt': 8063,
#  'tlk': 7387,
#  'chennai': 1873,
#  'velachery': 7746,
#  'kkwhy': 4203,
#  'search': 6370,
#  'job': 4055,
#  'theyll': 7299,
#  'understand': 7617,
#  'wine': 8022,
#  'idea': 3797,
#  'slurp': 6654,
#  'flaked': 3024,
#  'shits': 6507,
#  'seriously': 6434,
#  'goin': 3322,
#  'roommate': 6215,
#  'tonight': 7440,
#  'sary': 6310,
#  'need': 5040,
#  'tim': 7362,
#  'bollox': 1503,
#  'lot': 4488,
#  'tol': 7417,
#  'lobby': 4441,
#  'anybodys': 1071,
#  'still': 6920,
#  'havent': 3523,
#  'thought': 7326,
#  'tactful': 7124,
#  'ask': 1170,
#  'alex': 982,
#  'doc': 2508,
#  'nice': 5086,
#  'shirt': 6500,
#  'hubby': 3739,
#  'fiting': 3015,
#  'budget': 1637,
#  'load': 4437,
#  'card': 1754,
#  'abi': 821,
#  'hwkeep': 3776,
#  'posted': 5708,
#  'luv': 4556,
#  'mj': 4831,
#  'frnd': 3156,
#  'ashwini': 1167,
#  'college': 2005,
#  'lmao': 4433,
#  'wont': 8078,
#  'needing': 5044,
#  'hair': 3470,
#  'anymore': 1073,
#  'swing': 7103,
#  'firsg': 3009,
#  'yesfrom': 8258,
#  'problem': 5812,
#  'baby': 1267,
#  'called': 1711,
#  'every': 2802,
#  'king': 4183,
#  'crying': 2208,
#  'building': 1644,
#  'map': 4635,
#  'imprtant': 3844,
#  'wil': 8011,
#  'tomorw': 7432,
#  'themobyo': 7282,
#  'yo': 8275,
#  'yohere': 8278,
#  'comes': 2018,
#  'selection': 6403,
#  'hot': 3698,
#  'downloads': 2563,
#  'members': 4723,
#  'click': 1956,
#  'open': 5320,
#  'link': 4405,
#  'street': 6955,
#  'library': 4367,
#  'walk': 7847,
#  'decided': 2337,
#  'stuff': 6982,
#  'vote': 7808,
#  'caring': 1767,
#  'losers': 4483,
#  'ned': 5039,
#  'convince': 2112,
#  'tht': 7344,
#  'possible': 5703,
#  'witot': 8047,
#  'hurting': 3767,
#  'main': 4607,
#  'email': 2706,
#  'ûò': 8340,
#  'address': 884,
#  'incomm': 3855,
#  'hellodrivby0quit': 3562,
#  'edrunk': 2661,
#  'iff': 3805,
#  'pthis': 5870,
#  'makes': 4612,
#  'senrddnot': 6419,
#  'dancce': 2265,
#  'drum': 2603,
#  'basqihave': 1320,
#  'fun': 3181,
#  '2nhite': 442,
#  'ros': 6218,
#  'xxxxxxx': 8221,
#  'someone': 6715,
#  'conacted': 2059,
#  'dating': 2292,
#  'entered': 2743,
#  'fancy': 2912,
#  'youto': 8299,
#  'find': 2992,
#  'landline': 4271,
#  '09111030116': 238,
#  'pobox12n146tf15': 5640,
#  'apparently': 1092,
#  'retired': 6152,
#  'trust': 7529,
#  'mmmmm': 4838,
#  'sooooo': 6748,
#  'wake': 7843,
#  'morning': 4898,
#  'mmmm': 4837,
#  'lion': 4408,
#  'devouring': 2418,
#  'across': 863,
#  'sea': 6369,
#  'finns': 3005,
#  'wait': 7837,
#  'wesleys': 7960,
#  'bet': 1406,
#  'hella': 3560,
#  'drugs': 2602,
#  'especially': 2774,
#  'class': 1942,
#  'wednesday': 7922,
#  'probably': 5811,
#  'failed': 2888,
#  'test': 7235,
#  'friday': 3141,
#  'lead': 4318,
#  'thanks': 7258,
#  'honey': 3667,
#  'heard': 3539,
#  'longer': 4466,
#  'crowd': 2201,
#  'advice': 906,
#  'cardiff': 1755,
#  'decision': 2340,
#  'decide': 2336,
#  'would': 8120,
#  'simpler': 6577,
#  'magical': 4598,
#  'hasnt': 3515,
#  'pattern': 5477,
#  'recently': 6014,
#  'crap': 2174,
#  'weekends': 7929,
#  'around': 1146,
#  'pm': 5634,
#  'hospital': 3693,
#  'perumbavoor': 5533,
#  'offer': 5246,
#  'video': 7765,
#  'handset': 3486,
#  '750': 676,
#  'anytime': 1081,
#  'networks': 5064,
#  'unlimited': 7642,
#  'camcorder': 1726,
#  '08000930705': 41,
#  'noits': 5133,
#  'ful': 3177,
#  'song': 6735,
#  'lyrics': 4566,
#  'company': 2033,
#  'elama': 2692,
#  'po': 5636,
#  'mudyadhu': 4952,
#  'cause': 1794,
#  'old': 5289,
#  'high': 3603,
#  'cos': 2134,
#  'darren': 2284,
#  'considering': 2089,
#  'mah': 4599,
#  'nottel': 5175,
#  'software': 6705,
#  'lick': 4368,
#  'mouth': 4914,
#  'freezing': 3134,
#  'craving': 2179,
#  'ice': 3789,
#  'fml': 3052,
#  'winner': 8025,
#  'selected': 6402,
#  'receive': 6009,
#  '2000': 374,
#  'award': 1245,
#  'speak': 6783,
#  'operator': 5327,
#  'claim': 1935,
#  '087147123779am7pm': 105,
#  '10p': 261,
#  'whats': 7972,
#  'online': 5305,
#  'accounts': 854,
#  'trade': 7483,
#  'half': 3474,
#  'buy': 1668,
#  'credit': 2186,
#  'waiting': 7840,
#  'entry': 2752,
#  'wkly': 8055,
#  'comp': 2031,
#  'fa': 2875,
#  'cup': 2222,
#  'final': 2989,
#  'tkts': 7386,
#  '21st': 389,
#  '2005': 378,
#  '87121': 758,
#  'questionstd': 5914,
#  'txt': 7569,
#  'ratetcs': 5960,
#  '08452810075over18s': 60,
#  'depends': 2386,
#  'wan': 7860,
#  'hai': 3469,
#  'ana': 1036,
#  'tomarrow': 7424,
#  'ltdecimalgt': 4532,
#  'sathy': 6314,
#  'rto': 6240,
#  'came': 1727,
#  'big': 1423,
#  'scraped': 6354,
#  'barrel': 1312,
#  'shower': 6538,
#  'social': 6702,
#  'misfits': 4808,
#  'change': 1830,
#  'windows': 8020,
#  'logoff': 4453,
#  'flatter': 3029,
#  'mine': 4788,
#  'pints': 5583,
#  'carlin': 1769,
#  'ten': 7218,
#  'minutes': 4801,
#  'cashbalance': 1782,
#  '500': 589,
#  'pounds': 5718,
#  'maximize': 4677,
#  'cashin': 1785,
#  '86688': 752,
#  '150pmeg': 307,
#  'cc': 1799,
#  '08718720201': 129,
#  'hgsuite3422lands': 3596,
#  'roww1j6hl': 6227,
#  'rightio': 6176,
#  '1148': 269,
#  'arent': 1126,
#  'bright': 1589,
#  'early': 2637,
#  'boston': 1527,
#  'personal': 5527,
#  'statement': 6891,
#  'woulda': 8121,
#  'changed': 1831,
#  ...}

# %%
# How are these vectors stored?
X_test_vect[0]
# Out:
# <1x8342 sparse matrix of type '<class 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to arrays?
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 1.0 / Recall: 0.794 / Accuracy: 0.971
